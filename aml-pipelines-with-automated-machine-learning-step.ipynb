# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# udacity-ws
# udacity-ml
# eastus
# 12d8a290-6d86-4923-bc31-637a3ee790ed

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'udacity-exp'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: udacity-exp,
# Workspace: udacity-ws)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "udacity-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "bankmarketing_train"
description_text = ""

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [ac95b43c][12b8aa81-0833-404f-b2f7-423b9047b67f], (This step will run and generate new outputs)
# Submitted PipelineRun 502873fa-a4d3-488e-95f6-ccffe75469a0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-exp/runs/502873fa-a4d3-488e-95f6-ccffe75469a0?wsid=/subscriptions/12d8a290-6d86-4923-bc31-637a3ee790ed/resourcegroups/udacity-ml/workspaces/udacity-ws

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 502873fa-a4d3-488e-95f6-ccffe75469a0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-exp/runs/502873fa-a4d3-488e-95f6-ccffe75469a0?wsid=/subscriptions/12d8a290-6d86-4923-bc31-637a3ee790ed/resourcegroups/udacity-ml/workspaces/udacity-ws
# PipelineRun Status: Running
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '502873fa-a4d3-488e-95f6-ccffe75469a0', 'status': 'Completed', 'startTimeUtc': '2020-12-30T09:35:21.51367Z', 'endTimeUtc': '2020-12-30T10:22:28.272662Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://udacityws4475506727.blob.core.windows.net/azureml/ExperimentRun/dcid.502873fa-a4d3-488e-95f6-ccffe75469a0/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=066Sn8nyWgAXYXcvPafcLcOFnv0Yg53FN%2FBmQtPwATI%3D&st=2020-12-30T09%3A25%3A26Z&se=2020-12-30T17%3A35%3A26Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://udacityws4475506727.blob.core.windows.net/azureml/ExperimentRun/dcid.502873fa-a4d3-488e-95f6-ccffe75469a0/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=JIMC31vdkvuW84Xt%2BVCdDB%2B0axZU53As8qAf2%2BsYWw8%3D&st=2020-12-30T09%3A25%3A26Z&se=2020-12-30T17%3A35%3A26Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://udacityws4475506727.blob.core.windows.net/azureml/ExperimentRun/dcid.502873fa-a4d3-488e-95f6-ccffe75469a0/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=jG6gEj54dRJ6C7eyWq1kOknQLtrYCUSIDFLLGhpqbC4%3D&st=2020-12-30T09%3A25%3A26Z&se=2020-12-30T17%3A35%3A26Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d74d66c8-d381-445d-9043-362a5293da98/metrics_data
# Downloaded azureml/d74d66c8-d381-445d-9043-362a5293da98/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  d74d66c8-d381-445d-9043-362a5293da98_10  \
# precision_score_weighted                            [0.8845347242903908]
# weighted_accuracy                                   [0.7698999164945606]
# AUC_micro                                           [0.8517626145283815]
# average_precision_score_micro                        [0.832043036295493]
# matthews_correlation                               [0.35750409793144705]
# norm_macro_recall                                   [0.5128823537039198]
# average_precision_score_weighted                    [0.9227984662127822]
# recall_score_macro                                  [0.7564411768519599]
# precision_score_macro                               [0.6245989251870032]
# f1_score_macro                                       [0.635663597210459]
# accuracy                                            [0.7672230652503793]
# AUC_weighted                                        [0.8671058651803196]
# log_loss                                            [0.5162769059983477]
# AUC_macro                                           [0.8671058651803196]
# f1_score_weighted                                   [0.8055613546741338]
# recall_score_weighted                               [0.7672230652503793]
# recall_score_micro                                  [0.7672230652503793]
# average_precision_score_macro                       [0.7219872326230068]
# balanced_accuracy                                   [0.7564411768519599]
# f1_score_micro                                      [0.7672230652503793]
# precision_score_micro                               [0.7672230652503793]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_7  \
# precision_score_weighted                            [0.788565560086672]
# weighted_accuracy                                  [0.9843450583187134]
# AUC_micro                                          [0.9593308479993369]
# average_precision_score_micro                      [0.9599083925817044]
# matthews_correlation                                              [0.0]
# norm_macro_recall                                                 [0.0]
# average_precision_score_weighted                   [0.9222106478383083]
# recall_score_macro                                                [0.5]
# precision_score_macro                              [0.4440060698027314]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# AUC_weighted                                       [0.8585779859849181]
# log_loss                                          [0.27483431960274407]
# AUC_macro                                          [0.8585779859849181]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_weighted                              [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# average_precision_score_macro                      [0.7261522723529075]
# balanced_accuracy                                                 [0.5]
# f1_score_micro                                     [0.8880121396054628]
# precision_score_micro                              [0.8880121396054628]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_14  \
# precision_score_weighted                             [0.788565560086672]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9669036407303105]
# average_precision_score_micro                       [0.9681023822331165]
# matthews_correlation                                               [0.0]
# norm_macro_recall                                                  [0.0]
# average_precision_score_weighted                    [0.9313563099359664]
# recall_score_macro                                                 [0.5]
# precision_score_macro                               [0.4440060698027314]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# AUC_weighted                                        [0.8966526626988758]
# log_loss                                           [0.26566880062988385]
# AUC_macro                                           [0.8966526626988758]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_weighted                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_macro                       [0.7432430110761905]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_8  \
# precision_score_weighted                            [0.788565560086672]
# weighted_accuracy                                  [0.9843450583187134]
# AUC_micro                                          [0.9655112703526058]
# average_precision_score_micro                      [0.9653854502120272]
# matthews_correlation                                              [0.0]
# norm_macro_recall                                                 [0.0]
# average_precision_score_weighted                   [0.9265459256677528]
# recall_score_macro                                                [0.5]
# precision_score_macro                              [0.4440060698027314]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# AUC_weighted                                       [0.8896520680859576]
# log_loss                                          [0.27492475142105904]
# AUC_macro                                          [0.8896520680859576]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_weighted                              [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# average_precision_score_macro                      [0.7313824408012801]
# balanced_accuracy                                                 [0.5]
# f1_score_micro                                     [0.8880121396054628]
# precision_score_micro                              [0.8880121396054628]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_2  \
# precision_score_weighted                           [0.8649413679089326]
# weighted_accuracy                                  [0.9801079304643319]
# AUC_micro                                           [0.968766674111923]
# average_precision_score_micro                       [0.969783838292346]
# matthews_correlation                              [0.18812462809051092]
# norm_macro_recall                                  [0.0677025157127853]
# average_precision_score_weighted                     [0.93307727166608]
# recall_score_macro                                 [0.5338512578563926]
# precision_score_macro                              [0.7613704625418347]
# f1_score_macro                                     [0.5365602026608668]
# accuracy                                            [0.891350531107739]
# AUC_weighted                                       [0.9054570091155457]
# log_loss                                          [0.23789839868829737]
# AUC_macro                                          [0.9054570091155458]
# f1_score_weighted                                  [0.8512320270932818]
# recall_score_weighted                               [0.891350531107739]
# recall_score_micro                                  [0.891350531107739]
# average_precision_score_macro                      [0.7471965186757974]
# balanced_accuracy                                  [0.5338512578563926]
# f1_score_micro                                      [0.891350531107739]
# precision_score_micro                               [0.891350531107739]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_6  \
# precision_score_weighted                           [0.8840533097056155]
# weighted_accuracy                                  [0.9781043977806846]
# AUC_micro                                          [0.9654539802570226]
# average_precision_score_micro                      [0.9667312850842196]
# matthews_correlation                               [0.3264677270834346]
# norm_macro_recall                                  [0.1723442012273848]
# average_precision_score_weighted                   [0.9275394704634945]
# recall_score_macro                                 [0.5861721006136924]
# precision_score_macro                              [0.8092102202104395]
# f1_score_macro                                     [0.6178600472856574]
# accuracy                                           [0.9001517450682853]
# AUC_weighted                                       [0.8875588824240943]
# log_loss                                            [0.253437712936035]
# AUC_macro                                          [0.8875588824240942]
# f1_score_weighted                                   [0.872739945318913]
# recall_score_weighted                              [0.9001517450682853]
# recall_score_micro                                 [0.9001517450682853]
# average_precision_score_macro                      [0.7304743542500098]
# balanced_accuracy                                  [0.5861721006136924]
# f1_score_micro                                     [0.9001517450682853]
# precision_score_micro                              [0.9001517450682853]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_21  \
# precision_score_weighted                            [0.8859664258327548]
# weighted_accuracy                                   [0.9793227746800656]
# AUC_micro                                           [0.9744804861368561]
# average_precision_score_micro                       [0.9756497344937594]
# matthews_correlation                                [0.3256750549961802]
# norm_macro_recall                                  [0.16558117392520466]
# average_precision_score_weighted                     [0.945222197717833]
# recall_score_macro                                  [0.5827905869626023]
# precision_score_macro                               [0.8202786854702324]
# f1_score_macro                                      [0.6136146528695394]
# accuracy                                            [0.9004552352048558]
# AUC_weighted                                        [0.9304904908242522]
# log_loss                                           [0.22589233807484954]
# AUC_macro                                           [0.9304904908242521]
# f1_score_weighted                                   [0.8719631449552753]
# recall_score_weighted                               [0.9004552352048558]
# recall_score_micro                                  [0.9004552352048558]
# average_precision_score_macro                        [0.787108791806625]
# balanced_accuracy                                   [0.5827905869626023]
# f1_score_micro                                      [0.9004552352048558]
# precision_score_micro                               [0.9004552352048558]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_11  \
# precision_score_weighted                            [0.8905713130419389]
# weighted_accuracy                                   [0.7385800304151577]
# AUC_micro                                            [0.846473043950806]
# average_precision_score_micro                       [0.8559740945615143]
# matthews_correlation                               [0.36571749533932235]
# norm_macro_recall                                   [0.5424036810429622]
# average_precision_score_weighted                    [0.9244526361998561]
# recall_score_macro                                  [0.7712018405214811]
# precision_score_macro                               [0.6232931219604624]
# f1_score_macro                                      [0.6256544757539658]
# accuracy                                            [0.7450682852807283]
# AUC_weighted                                        [0.8713163174010414]
# log_loss                                            [0.5073907832691814]
# AUC_macro                                           [0.8713163174010414]
# f1_score_weighted                                    [0.789728151713091]
# recall_score_weighted                               [0.7450682852807283]
# recall_score_micro                                  [0.7450682852807283]
# average_precision_score_macro                       [0.7265098590606996]
# balanced_accuracy                                   [0.7712018405214811]
# f1_score_micro                                      [0.7450682852807284]
# precision_score_micro                               [0.7450682852807283]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_12  \
# precision_score_weighted                            [0.8796073837253447]
# weighted_accuracy                                   [0.7275967024146904]
# AUC_micro                                           [0.8297517966477925]
# average_precision_score_micro                       [0.8169046152715946]
# matthews_correlation                                [0.3197327333007261]
# norm_macro_recall                                   [0.4752402069475239]
# average_precision_score_weighted                    [0.9191016880061069]
# recall_score_macro                                   [0.737620103473762]
# precision_score_macro                                [0.607555105028436]
# f1_score_macro                                      [0.6047129163507636]
# accuracy                                            [0.7295902883156298]
# AUC_weighted                                         [0.847932840230658]
# log_loss                                            [0.5883462974384038]
# AUC_macro                                           [0.8479328402306578]
# f1_score_weighted                                   [0.7771273008616507]
# recall_score_weighted                               [0.7295902883156298]
# recall_score_micro                                  [0.7295902883156298]
# average_precision_score_macro                       [0.7187382365098436]
# balanced_accuracy                                    [0.737620103473762]
# f1_score_micro                                      [0.7295902883156298]
# precision_score_micro                               [0.7295902883156298]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_1  ...  \
# precision_score_weighted                           [0.8991976076061607]  ...
# weighted_accuracy                                  [0.9537972210153172]  ...
# AUC_micro                                          [0.9781770788959222]  ...
# average_precision_score_micro                      [0.9791945367231853]  ...
# matthews_correlation                                [0.488678780261868]  ...
# norm_macro_recall                                 [0.43834549418631563]  ...
# average_precision_score_weighted                   [0.9505970434373063]  ...
# recall_score_macro                                 [0.7191727470931578]  ...
# precision_score_macro                              [0.7723958081530135]  ...
# f1_score_macro                                     [0.7416848907681176]  ...
# accuracy                                           [0.9071320182094081]  ...
# AUC_weighted                                       [0.9392346349984347]  ...
# log_loss                                           [0.1874363495858499]  ...
# AUC_macro                                          [0.9392346349984347]  ...
# f1_score_weighted                                  [0.9021127651963996]  ...
# recall_score_weighted                              [0.9071320182094081]  ...
# recall_score_micro                                 [0.9071320182094081]  ...
# average_precision_score_macro                      [0.8065229883244922]  ...
# balanced_accuracy                                  [0.7191727470931578]  ...
# f1_score_micro                                     [0.9071320182094081]  ...
# precision_score_micro                              [0.9071320182094081]  ...
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_27  \
# precision_score_weighted                            [0.9091673500117678]
# weighted_accuracy                                    [0.955739817607932]
# AUC_micro                                           [0.9793262887393186]
# average_precision_score_micro                        [0.980265476028581]
# matthews_correlation                                [0.5405681061962972]
# norm_macro_recall                                   [0.4989913808912525]
# average_precision_score_weighted                    [0.9527361347117024]
# recall_score_macro                                  [0.7494956904456263]
# precision_score_macro                               [0.7928045339327563]
# f1_score_macro                                       [0.768705561013824]
# accuracy                                            [0.9147192716236723]
# AUC_weighted                                         [0.943113511791304]
# log_loss                                           [0.20115476792555329]
# AUC_macro                                           [0.9431135117913039]
# f1_score_weighted                                   [0.9113171187026634]
# recall_score_weighted                               [0.9147192716236723]
# recall_score_micro                                  [0.9147192716236723]
# average_precision_score_macro                       [0.8143325266138632]
# balanced_accuracy                                   [0.7494956904456263]
# f1_score_micro                                      [0.9147192716236722]
# precision_score_micro                               [0.9147192716236723]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_16  \
# precision_score_weighted                            [0.8838727921327303]
# weighted_accuracy                                   [0.8333457696613461]
# AUC_micro                                           [0.8389530281085287]
# average_precision_score_micro                       [0.8056342186337094]
# matthews_correlation                               [0.38429160260763384]
# norm_macro_recall                                   [0.5053302139309841]
# average_precision_score_weighted                    [0.9159860753526562]
# recall_score_macro                                   [0.752665106965492]
# precision_score_macro                               [0.6461223094953442]
# f1_score_macro                                      [0.6705779230959321]
# accuracy                                             [0.817298937784522]
# AUC_weighted                                        [0.8503339835175521]
# log_loss                                            [0.5168894831233535]
# AUC_macro                                           [0.8503339835175522]
# f1_score_weighted                                   [0.8411853057965799]
# recall_score_weighted                                [0.817298937784522]
# recall_score_micro                                   [0.817298937784522]
# average_precision_score_macro                       [0.7089134138348921]
# balanced_accuracy                                    [0.752665106965492]
# f1_score_micro                                      [0.8172989377845219]
# precision_score_micro                                [0.817298937784522]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_3  \
# precision_score_weighted                            [0.896480829793996]
# weighted_accuracy                                   [0.807162911029743]
# AUC_micro                                          [0.8658707150439463]
# average_precision_score_micro                      [0.8394589654502049]
# matthews_correlation                               [0.4237089589258037]
# norm_macro_recall                                  [0.5880749545704615]
# average_precision_score_weighted                   [0.9314767314882281]
# recall_score_macro                                 [0.7940374772852308]
# precision_score_macro                              [0.6526414961891372]
# f1_score_macro                                     [0.6761028177183503]
# accuracy                                           [0.8045523520485585]
# AUC_weighted                                       [0.8900637588057357]
# log_loss                                          [0.49457778252803186]
# AUC_macro                                          [0.8900637588057356]
# f1_score_weighted                                  [0.8343897860471898]
# recall_score_weighted                              [0.8045523520485585]
# recall_score_micro                                 [0.8045523520485585]
# average_precision_score_macro                      [0.7464846949668471]
# balanced_accuracy                                  [0.7940374772852308]
# f1_score_micro                                     [0.8045523520485584]
# precision_score_micro                              [0.8045523520485585]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_18  \
# precision_score_weighted                            [0.8877784948285489]
# weighted_accuracy                                    [0.703383919103545]
# AUC_micro                                           [0.8373790241801967]
# average_precision_score_micro                       [0.8466197439180351]
# matthews_correlation                                [0.3389529667555448]
# norm_macro_recall                                   [0.5146485948796604]
# average_precision_score_weighted                     [0.923461141294629]
# recall_score_macro                                  [0.7573242974398302]
# precision_score_macro                               [0.6116189909148104]
# f1_score_macro                                      [0.6012482502605339]
# accuracy                                            [0.7141122913505311]
# AUC_weighted                                        [0.8684868120041419]
# log_loss                                            [0.5657934144633485]
# AUC_macro                                           [0.8684868120041419]
# f1_score_weighted                                   [0.7658765178401818]
# recall_score_weighted                               [0.7141122913505311]
# recall_score_micro                                  [0.7141122913505311]
# average_precision_score_macro                       [0.7225483962256298]
# balanced_accuracy                                   [0.7573242974398302]
# f1_score_micro                                      [0.7141122913505311]
# precision_score_micro                               [0.7141122913505311]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_9  \
# precision_score_weighted                           [0.8774395924809395]
# weighted_accuracy                                    [0.72839381546965]
# AUC_micro                                          [0.8223610058924982]
# average_precision_score_micro                      [0.7899265580504549]
# matthews_correlation                              [0.31191095292324544]
# norm_macro_recall                                 [0.46271536194514384]
# average_precision_score_weighted                   [0.9111899363920701]
# recall_score_macro                                 [0.7313576809725719]
# precision_score_macro                               [0.605127742187454]
# f1_score_macro                                     [0.6022352372616148]
# accuracy                                           [0.7289833080424886]
# AUC_weighted                                       [0.8233416134571463]
# log_loss                                           [0.5596641073577211]
# AUC_macro                                          [0.8233416134571463]
# f1_score_weighted                                  [0.7764797625232785]
# recall_score_weighted                              [0.7289833080424886]
# recall_score_micro                                 [0.7289833080424886]
# average_precision_score_macro                      [0.7098272920025794]
# balanced_accuracy                                  [0.7313576809725719]
# f1_score_micro                                     [0.7289833080424885]
# precision_score_micro                              [0.7289833080424886]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_13  \
# precision_score_weighted                            [0.8929725418691179]
# weighted_accuracy                                   [0.9766010009385309]
# AUC_micro                                           [0.9758990146932517]
# average_precision_score_micro                       [0.9766643355999638]
# matthews_correlation                                [0.3976739324324451]
# norm_macro_recall                                  [0.24549085203770704]
# average_precision_score_weighted                     [0.947605275820125]
# recall_score_macro                                  [0.6227454260188535]
# precision_score_macro                                [0.822098675416211]
# f1_score_macro                                      [0.6650154684677185]
# accuracy                                            [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# log_loss                                           [0.33655623030329523]
# AUC_macro                                           [0.9308878256246677]
# f1_score_weighted                                    [0.885603431576398]
# recall_score_weighted                               [0.9062215477996965]
# recall_score_micro                                  [0.9062215477996965]
# average_precision_score_macro                       [0.7985126174047921]
# balanced_accuracy                                   [0.6227454260188535]
# f1_score_micro                                      [0.9062215477996965]
# precision_score_micro                               [0.9062215477996965]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_17  \
# precision_score_weighted                            [0.8797383122958395]
# weighted_accuracy                                   [0.7422291824779536]
# AUC_micro                                            [0.830562976505995]
# average_precision_score_micro                        [0.804150418835105]
# matthews_correlation                               [0.32650631853343004]
# norm_macro_recall                                  [0.47943769253140234]
# average_precision_score_weighted                    [0.9172742745917049]
# recall_score_macro                                  [0.7397188462657012]
# precision_score_macro                               [0.6111785511474686]
# f1_score_macro                                      [0.6130764003159918]
# accuracy                                            [0.7417298937784522]
# AUC_weighted                                        [0.8373136277500847]
# log_loss                                            [0.5573882647028073]
# AUC_macro                                           [0.8373136277500848]
# f1_score_weighted                                   [0.7862169175704715]
# recall_score_weighted                               [0.7417298937784522]
# recall_score_micro                                  [0.7417298937784522]
# average_precision_score_macro                       [0.7226809070187689]
# balanced_accuracy                                   [0.7397188462657012]
# f1_score_micro                                      [0.7417298937784522]
# precision_score_micro                               [0.7417298937784522]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_26  \
# precision_score_weighted                            [0.9009588586937793]
# weighted_accuracy                                   [0.9580008915065092]
# AUC_micro                                           [0.9796462658969652]
# average_precision_score_micro                       [0.9806060858226576]
# matthews_correlation                                [0.4949696826617772]
# norm_macro_recall                                   [0.4319483112807889]
# average_precision_score_weighted                    [0.9534515382439902]
# recall_score_macro                                  [0.7159741556403945]
# precision_score_macro                               [0.7835929442898562]
# f1_score_macro                                      [0.7433685547119313]
# accuracy                                            [0.9098634294385433]
# AUC_weighted                                        [0.9446556153873228]
# log_loss                                            [0.1902276361125012]
# AUC_macro                                           [0.9446556153873227]
# f1_score_weighted                                   [0.9037782738814667]
# recall_score_weighted                               [0.9098634294385433]
# recall_score_micro                                  [0.9098634294385433]
# average_precision_score_macro                       [0.8165813612270765]
# balanced_accuracy                                   [0.7159741556403945]
# f1_score_micro                                      [0.9098634294385431]
# precision_score_micro                               [0.9098634294385433]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_15  \
# precision_score_weighted                             [0.788565560086672]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9649967647675123]
# average_precision_score_micro                       [0.9657648593405217]
# matthews_correlation                                               [0.0]
# norm_macro_recall                                                  [0.0]
# average_precision_score_weighted                    [0.9202320798753159]
# recall_score_macro                                                 [0.5]
# precision_score_macro                               [0.4440060698027314]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# AUC_weighted                                        [0.8870652240356988]
# log_loss                                            [0.2547175246992988]
# AUC_macro                                           [0.8870652240356989]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_weighted                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_macro                       [0.6985212194771053]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
#
#                                  d74d66c8-d381-445d-9043-362a5293da98_4
# precision_score_weighted                            [0.788565560086672]
# weighted_accuracy                                  [0.9843450583187134]
# AUC_micro                                          [0.9645420361471029]
# average_precision_score_micro                      [0.9651334151046325]
# matthews_correlation                                              [0.0]
# norm_macro_recall                                                 [0.0]
# average_precision_score_weighted                   [0.9254408809118287]
# recall_score_macro                                                [0.5]
# precision_score_macro                              [0.4440060698027314]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# AUC_weighted                                       [0.8847789281037034]
# log_loss                                           [0.2705735507117315]
# AUC_macro                                          [0.8847789281037035]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_weighted                              [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# average_precision_score_macro                       [0.725986042795928]
# balanced_accuracy                                                 [0.5]
# f1_score_micro                                     [0.8880121396054628]
# precision_score_micro                              [0.8880121396054628]
#
# [21 rows x 24 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d74d66c8-d381-445d-9043-362a5293da98/model_data
# Downloaded azureml/d74d66c8-d381-445d-9043-362a5293da98/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                      importance_type='split',
#                                                                      learning_rate=0.1,
#                                                                      max_depth=-1,
#                                                                      min_child_samples=20,
#                                                                      min_child_weight=0.001,
#                                                                      min_split_gain=0.0,
#                                                                      n_estimators=100,
#                                                                      n_jobs=1,
#                                                                      num_leaves=31,
#                                                                      objective=None,
#                                                                      random_state=None,
#                                                                      reg_alpha=0.0,
#                                                                      reg_lambda=0.0,
#                                                                      silent=True,
#                                                                      subsample=1.0,
#                                                                      subsample_for_bin=200000,
#                                                                      subsample_freq=0,
#                                                                      verbose=-10))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('MaxAbsScaler', MaxAbsScaler(copy=True)),
#  ('LightGBMClassifier',
#   LightGBMClassifier(boosting_type='gbdt', class_weight=None,
#                      colsample_bytree=1.0, importance_type='split',
#                      learning_rate=0.1, max_depth=-1, min_child_samples=20,
#                      min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#                      n_jobs=1, num_leaves=31, objective=None, random_state=None,
#                      reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
#                      subsample_for_bin=200000, subsample_freq=0, verbose=-10))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_b6375932_4a95_11eb_892b_0022481deb31row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_b6375932_4a95_11eb_892b_0022481deb31row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b6375932_4a95_11eb_892b_0022481deb31row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b6375932_4a95_11eb_892b_0022481deb31row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_b6375932_4a95_11eb_892b_0022481deb31" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6375932_4a95_11eb_892b_0022481deb31level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b6375932_4a95_11eb_892b_0022481deb31row0_col0" class="data row0 col0" >28431</td>
#                         <td id="T_b6375932_4a95_11eb_892b_0022481deb31row0_col1" class="data row0 col1" >827</td>
#             </tr>
#             <tr>
#                         <th id="T_b6375932_4a95_11eb_892b_0022481deb31level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b6375932_4a95_11eb_892b_0022481deb31row1_col0" class="data row1 col0" >1246</td>
#                         <td id="T_b6375932_4a95_11eb_892b_0022481deb31row1_col1" class="data row1 col1" >2446</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 92bdbec6-e68a-4da4-b573-fc71bc6ad0cb,
# Status: Active,
# Endpoint: https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/12d8a290-6d86-4923-bc31-637a3ee790ed/resourceGroups/udacity-ml/providers/Microsoft.MachineLearningServices/workspaces/udacity-ws/PipelineRuns/PipelineSubmit/92bdbec6-e68a-4da4-b573-fc71bc6ad0cb)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  fb0a6644-9bec-4c4e-8a5c-cacf7ff75d4c

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
